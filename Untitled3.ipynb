# %%
import numpy as np
import pandas as pd

# %%
data ={
    "Name":["Samruddhi","shravni","mrunali","archita","pooja","sailee"],
    "Age":[44,36,np.nan,89,18,np.nan],
    "City":["Mumbai","pune",np.nan,"Shambhajinagar","Amravati","Ahmdabad"],
    "Salary":[20000,40000,np.nan,40000,100,1000000
             ]
      }
data
# Out:
# {'Name': ['Samruddhi', 'shravni', 'mrunali', 'archita', 'pooja', 'sailee'],
#  'Age': [44, 36, nan, 89, 18, nan],
#  'City': ['Mumbai', 'pune', nan, 'Shambhajinagar', 'Amravati', 'Ahmdabad'],
#  'Salary': [20000, 40000, nan, 40000, 100, 1000000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#         Name   Age            City     Salary
# 0  Samruddhi  44.0          Mumbai    20000.0
# 1    shravni  36.0            pune    40000.0
# 2    mrunali   NaN             NaN        NaN
# 3    archita  89.0  Shambhajinagar    40000.0
# 4      pooja  18.0        Amravati      100.0
# 5     sailee   NaN        Ahmdabad  1000000.0

# %%
df["Name"]
# Out:
# 0    Samruddhi
# 1      shravni
# 2      mrunali
# 3      archita
# 4        pooja
# 5       sailee
# Name: Name, dtype: object

# %%
df.iloc[0:3]
# Out:
#         Name   Age    City   Salary
# 0  Samruddhi  44.0  Mumbai  20000.0
# 1    shravni  36.0    pune  40000.0
# 2    mrunali   NaN     NaN      NaN

# %%
df.iloc[0:4,0:2]
# Out:
#         Name   Age
# 0  Samruddhi  44.0
# 1    shravni  36.0
# 2    mrunali   NaN
# 3    archita  89.0

# %%
df
# Out:
#         Name   Age            City     Salary
# 0  Samruddhi  44.0          Mumbai    20000.0
# 1    shravni  36.0            pune    40000.0
# 2    mrunali   NaN             NaN        NaN
# 3    archita  89.0  Shambhajinagar    40000.0
# 4      pooja  18.0        Amravati      100.0
# 5     sailee   NaN        Ahmdabad  1000000.0

# %%
df.head(2)
# Out:
#         Name   Age    City   Salary
# 0  Samruddhi  44.0  Mumbai  20000.0
# 1    shravni  36.0    pune  40000.0

# %%
df.tail()
# Out:
#       Name   Age            City     Salary
# 1  shravni  36.0            pune    40000.0
# 2  mrunali   NaN             NaN        NaN
# 3  archita  89.0  Shambhajinagar    40000.0
# 4    pooja  18.0        Amravati      100.0
# 5   sailee   NaN        Ahmdabad  1000000.0

# %%
df.head()
# Out:
#         Name   Age            City   Salary
# 0  Samruddhi  44.0          Mumbai  20000.0
# 1    shravni  36.0            pune  40000.0
# 2    mrunali   NaN             NaN      NaN
# 3    archita  89.0  Shambhajinagar  40000.0
# 4      pooja  18.0        Amravati    100.0

# %%
df.loc[[2,4],["City","Salary"]]
# Out:
#        City  Salary
# 2       NaN     NaN
# 4  Amravati   100.0

# %%
df[df["Age"] < 30]
# Out:
#     Name   Age      City  Salary
# 4  pooja  18.0  Amravati   100.0

# %%
df[df["City"] == "Ahmdabad"]
# Out:
#      Name  Age      City     Salary
# 5  sailee  NaN  Ahmdabad  1000000.0

# %%
df[df["Salary"] < 50000]
# Out:
#         Name   Age            City   Salary
# 0  Samruddhi  44.0          Mumbai  20000.0
# 1    shravni  36.0            pune  40000.0
# 3    archita  89.0  Shambhajinagar  40000.0
# 4      pooja  18.0        Amravati    100.0

# %%
df[df["City"].isin(["Amravati","Shambhajinagar"])]
# Out:
#       Name   Age            City   Salary
# 3  archita  89.0  Shambhajinagar  40000.0
# 4    pooja  18.0        Amravati    100.0

# %%
df
# Out:
#         Name   Age            City     Salary
# 0  Samruddhi  44.0          Mumbai    20000.0
# 1    shravni  36.0            pune    40000.0
# 2    mrunali   NaN             NaN        NaN
# 3    archita  89.0  Shambhajinagar    40000.0
# 4      pooja  18.0        Amravati      100.0
# 5     sailee   NaN        Ahmdabad  1000000.0

# %%
df.sort_values("Salary")
# Out:
#         Name   Age            City     Salary
# 4      pooja  18.0        Amravati      100.0
# 0  Samruddhi  44.0          Mumbai    20000.0
# 1    shravni  36.0            pune    40000.0
# 3    archita  89.0  Shambhajinagar    40000.0
# 5     sailee   NaN        Ahmdabad  1000000.0
# 2    mrunali   NaN             NaN        NaN

# %%
df.sort_values("Age")
# Out:
#         Name   Age            City     Salary
# 4      pooja  18.0        Amravati      100.0
# 1    shravni  36.0            pune    40000.0
# 0  Samruddhi  44.0          Mumbai    20000.0
# 3    archita  89.0  Shambhajinagar    40000.0
# 2    mrunali   NaN             NaN        NaN
# 5     sailee   NaN        Ahmdabad  1000000.0

# %%
df.sort_values("Age",ascending=False)
# Out:
#         Name   Age            City     Salary
# 3    archita  89.0  Shambhajinagar    40000.0
# 0  Samruddhi  44.0          Mumbai    20000.0
# 1    shravni  36.0            pune    40000.0
# 4      pooja  18.0        Amravati      100.0
# 2    mrunali   NaN             NaN        NaN
# 5     sailee   NaN        Ahmdabad  1000000.0

# %%
df.sort_values(by=['City', 'Age'], ascending=True)
# Out:
#         Name   Age            City     Salary
# 5     sailee   NaN        Ahmdabad  1000000.0
# 4      pooja  18.0        Amravati      100.0
# 0  Samruddhi  44.0          Mumbai    20000.0
# 3    archita  89.0  Shambhajinagar    40000.0
# 1    shravni  36.0            pune    40000.0
# 2    mrunali   NaN             NaN        NaN

# %%
df.isnull()
# Out:
#     Name    Age   City  Salary
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False   True   True    True
# 3  False  False  False   False
# 4  False  False  False   False
# 5  False   True  False   False

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       2
# City      1
# Salary    1
# dtype: int64

# %%
#df.dropna()

# %%
df
# Out:
#         Name   Age            City     Salary
# 0  Samruddhi  44.0          Mumbai    20000.0
# 1    shravni  36.0            pune    40000.0
# 2    mrunali   NaN             NaN        NaN
# 3    archita  89.0  Shambhajinagar    40000.0
# 4      pooja  18.0        Amravati      100.0
# 5     sailee   NaN        Ahmdabad  1000000.0

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#         Name    Age            City     Salary
# 0  Samruddhi  44.00          Mumbai    20000.0
# 1    shravni  36.00            pune    40000.0
# 2    mrunali  46.75             NaN        NaN
# 3    archita  89.00  Shambhajinagar    40000.0
# 4      pooja  18.00        Amravati      100.0
# 5     sailee  46.75        Ahmdabad  1000000.0

# %%
df["City"] = df["City"].fillna("Unknown")

# %%
df
# Out:
#         Name    Age            City     Salary
# 0  Samruddhi  44.00          Mumbai    20000.0
# 1    shravni  36.00            pune    40000.0
# 2    mrunali  46.75         Unknown        NaN
# 3    archita  89.00  Shambhajinagar    40000.0
# 4      pooja  18.00        Amravati      100.0
# 5     sailee  46.75        Ahmdabad  1000000.0

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].median())

# %%
df
# Out:
#         Name    Age            City     Salary
# 0  Samruddhi  44.00          Mumbai    20000.0
# 1    shravni  36.00            pune    40000.0
# 2    mrunali  46.75         Unknown    40000.0
# 3    archita  89.00  Shambhajinagar    40000.0
# 4      pooja  18.00        Amravati      100.0
# 5     sailee  46.75        Ahmdabad  1000000.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#         Name    Age            City     Salary
# 0  Samruddhi  44.00          Mumbai    20000.0
# 1    shravni  36.00            pune    40000.0
# 2    mrunali  46.75         Unknown    40000.0
# 3    archita  89.00  Shambhajinagar    40000.0
# 4      pooja  18.00        Amravati      100.0
# 5     sailee  46.75        Ahmdabad  1000000.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Tax"] = df["Salary"] = 0.05

# %%
df
# Out:
#         Name    Age            City  Salary   Tax  Experience Salary_status
# 0  SAMRUDDHI  44.00          mumbai    0.05  0.05           2           Low
# 1    SHRAVNI  36.00            pune    0.05  0.05           3           Low
# 2    MRUNALI  46.75         unknown    0.05  0.05           4           Low
# 3    ARCHITA  89.00  shambhajinagar    0.05  0.05           6           Low
# 4      POOJA  18.00        amravati    0.05  0.05           8           Low
# 5     SAILEE  46.75        ahmdabad    0.05  0.05           9           Low

# %%
df["City"] = df["City"].str.lower()

# %%
df
# Out:
#         Name    Age            City  Salary   Tax  Experience Salary_status
# 0  SAMRUDDHI  44.00          mumbai    0.05  0.05           2           Low
# 1    SHRAVNI  36.00            pune    0.05  0.05           3           Low
# 2    MRUNALI  46.75         unknown    0.05  0.05           4           Low
# 3    ARCHITA  89.00  shambhajinagar    0.05  0.05           6           Low
# 4      POOJA  18.00        amravati    0.05  0.05           8           Low
# 5     SAILEE  46.75        ahmdabad    0.05  0.05           9           Low

# %%
df["Name"] = df["Name"].str.upper()

# %%
df
# Out:
#         Name    Age            City  Salary   Tax  Experience Salary_status
# 0  SAMRUDDHI  44.00          mumbai    0.05  0.05           2           Low
# 1    SHRAVNI  36.00            pune    0.05  0.05           3           Low
# 2    MRUNALI  46.75         unknown    0.05  0.05           4           Low
# 3    ARCHITA  89.00  shambhajinagar    0.05  0.05           6           Low
# 4      POOJA  18.00        amravati    0.05  0.05           8           Low
# 5     SAILEE  46.75        ahmdabad    0.05  0.05           9           Low

# %%
df["Experience"] =  [2,3,4,6,8,9]

# %%
df
# Out:
#         Name    Age            City  Salary   Tax  Experience Salary_status
# 0  SAMRUDDHI  44.00          mumbai    0.05  0.05           2           Low
# 1    SHRAVNI  36.00            pune    0.05  0.05           3           Low
# 2    MRUNALI  46.75         unknown    0.05  0.05           4           Low
# 3    ARCHITA  89.00  shambhajinagar    0.05  0.05           6           Low
# 4      POOJA  18.00        amravati    0.05  0.05           8           Low
# 5     SAILEE  46.75        ahmdabad    0.05  0.05           9           Low

# %%
def salary_category(salary):
    if salary < 50000:
        return "Low"
    elif salary <= 60000:
        return "Medium"
    else:
        return "High"

print(salary_category(50000))
# Out:
# Medium

# %%
df["Salary_status"] = df["Salary"].apply(salary_category)

# %%
df
# Out:
#         Name    Age            City  Salary   Tax  Experience Salary_status
# 0  SAMRUDDHI  44.00          mumbai    0.05  0.05           2           Low
# 1    SHRAVNI  36.00            pune    0.05  0.05           3           Low
# 2    MRUNALI  46.75         unknown    0.05  0.05           4           Low
# 3    ARCHITA  89.00  shambhajinagar    0.05  0.05           6           Low
# 4      POOJA  18.00        amravati    0.05  0.05           8           Low
# 5     SAILEE  46.75        ahmdabad    0.05  0.05           9           Low
