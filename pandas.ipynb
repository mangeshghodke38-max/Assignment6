# %%
import numpy as np

# %%
import pandas as pd

# %%
list = ["salim","shubham","ashwin","sarthak","Mangesh"]
list
# Out:
# ['salim', 'shubham', 'ashwin', 'sarthak']

# %%
a = pd.Series(list)
a[2]
# Out:
# 'ashwin'

# %%
label = ['a','b','c','d']

# %%
a = pd.Series(list,index=label)
a
# Out:
# a      salim
# b    shubham
# c     ashwin
# d    sarthak
# dtype: object

# %%
arr = np.array(['india','japan','china','USA'])
arr
# Out:
# array(['india', 'japan', 'china', 'USA'], dtype='<U5')

# %%
b = pd.Series(arr)
b
# Out:
# 0    india
# 1    japan
# 2    china
# 3      USA
# dtype: object

# %%
label = ['country1','country2','country3','country4']

# %%
b = pd.Series(arr,index=label)
b
# Out:
# country1    india
# country2    japan
# country3    china
# country4      USA
# dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Mangesh', 'Ashwin', 'Sarthak', 'pradnya'],
    'Age': [20, 21, 19, 17],
    'City': ['Pune', 'Jalgaon', 'nashik', 'Nagpur'],
    'country':['india','japan','china','USA'],
    'salary' : [2000, 3000, 2300, 2345],
}

data
# Out:
# {'Name': ['Mangesh', 'Ashwin', 'Sarthak', 'pradnya'],
#  'Age': [20, 21, 19, 17],
#  'City': ['Pune', 'Jalgaon', 'nashik', 'Nagpur'],
#  'country': ['india', 'japan', 'china', 'USA'],
#  'salary': [2000, 3000, 2300, 2345]}

# %%
d = pd.DataFrame(data)
d
# Out:
#       Name  Age     City country  salary
# 0  Mangesh   20     Pune   india    2000
# 1   Ashwin   21  Jalgaon   japan    3000
# 2  Sarthak   19   nashik   china    2300
# 3  pradnya   17   Nagpur     USA    2345

# %%
a
# Out:
# a      salim
# b    shubham
# c     ashwin
# d    sarthak
# dtype: object

# %%
b
# Out:
# country1    india
# country2    japan
# country3    china
# country4      USA
# dtype: object

# %%
d
# Out:
#       Name  Age     City country  salary
# 0  Mangesh   20     Pune   india    2000
# 1   Ashwin   21  Jalgaon   japan    3000
# 2  Sarthak   19   nashik   china    2300
# 3  pradnya   17   Nagpur     USA    2345

# %%
df = pd.Series(data)

# %%
df
# Out:
# Name       [Mangesh, Ashwin, Sarthak, pradnya]
# Age                           [20, 21, 19, 17]
# City           [Pune, Jalgaon, nashik, Nagpur]
# country             [india, japan, china, USA]
# salary                [2000, 3000, 2300, 2345]
# dtype: object

# %%
list = ["Name","age","city","salary"]

# %%
list
# Out:
# ['Name', 'age', 'city', 'salary']

# %%
a = pd.DataFrame(data,columns=[ ["Name","age","city","salary"]])
a
# Out:
# Empty DataFrame
# Columns: [(Name,), (age,), (city,), (salary,)]
# Index: []

# %%
df
# Out:
# Name       [Mangesh, Ashwin, Sarthak, pradnya]
# Age                           [20, 21, 19, 17]
# City           [Pune, Jalgaon, nashik, Nagpur]
# country             [india, japan, china, USA]
# salary                [2000, 3000, 2300, 2345]
# dtype: object

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age     City country  salary
# 0  Mangesh   20     Pune   india    2000
# 1   Ashwin   21  Jalgaon   japan    3000
# 2  Sarthak   19   nashik   china    2300
# 3  pradnya   17   Nagpur     USA    2345

# %%
df["Name"]
# Out:
# 0    Mangesh
# 1     Ashwin
# 2    Sarthak
# 3    pradnya
# Name: Name, dtype: object

# %%
df[["Name","Age"]]
# Out:
#       Name  Age
# 0  Mangesh   20
# 1   Ashwin   21
# 2  Sarthak   19
# 3  pradnya   17

# %%
df
# Out:
#       Name  Age     City country  salary
# 0  Mangesh   20     Pune   india    2000
# 1   Ashwin   21  Jalgaon   japan    3000
# 2  Sarthak   19   nashik   china    2300
# 3  pradnya   17   Nagpur     USA    2345

# %% [markdown]
# ## df.iloc[[0,1]]

# %%
d.loc[[0,1],[["city","salary"]]
# Out:
#   Cell In[88], line 1
#     d.loc[[0,1],[["city","salary"]]
#                                    ^
# _IncompleteInputError: incomplete input

# %%
d[(d["age"] > 19) & (d["city"] == "pune"])
# Out:
#   Cell In[99], line 1
#     d[(d["age"] > 19) & (d["city"] == "pune"])
#                                             ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
