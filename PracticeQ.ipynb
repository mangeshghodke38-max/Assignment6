# %%
import numpy as np

# %% [markdown]
# # 1.Array Arithmatic Operator

# %%
arr1 = np.array([1,2,3,4,5])
arr2 = np.array([6,7,8,9,10])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr2
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
arr1 + arr2
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
arr1 - arr2
# Out:
# array([-5, -5, -5, -5, -5])

# %%
arr1 * arr2
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
arr1 / arr2
# Out:
# array([0.16666667, 0.28571429, 0.375     , 0.44444444, 0.5       ])

# %%
arr1 // arr2
# Out:
# array([0, 0, 0, 0, 0])

# %%
arr1 ** arr2
# Out:
# array([      1,     128,    6561,  262144, 9765625])

# %%
arr1.shape ==arr.shape
# Out:
# False

# %%
arr1.shape ==arr2.shape
# Out:
# True

# %% [markdown]
# # Broadcasting

# %%
arr1 = np.array([1,2,3,4,5])
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1 + 5
# Out:
# array([ 6,  7,  8,  9, 10])

# %% [markdown]
# # Array and Sclar

# %%
arr1 = np.array([1,2,3,4,5])
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1 - 5
# Out:
# array([-4, -3, -2, -1,  0])

# %%
arr1 * 5
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
arr1 / 5
# Out:
# array([0.2, 0.4, 0.6, 0.8, 1. ])

# %% [markdown]
# # Shape of Array

# %%
arr1 = np.array([1,2,3,4,5])
arr2 = np.array([6,7,8,9,10])
arr2
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
arr.shape
# Out:
# (9,)

# %%
arr2.shape
# Out:
# (5,)

# %% [markdown]
# # Row-Wise Broadcasting
