# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([100,200,300], index=['a','b','c'])
print(s)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
s = pd.Series({'x':5,'y':10,'z':15})
print(s)
# Out:
# x     5
# y    10
# z    15
# dtype: int64

# %%
print(s['y'])
# Out:
# 10

# %%
df = pd.DataFrame({
    'Name':['Rahul','Priya','Amit','Neha'],
    'Age':[22,21,23,22],
    'City':['Pune','Mumbai','Nashik','Delhi']
})
print(df)
# Out:
#     Name  Age    City
# 0  Rahul   22    Pune
# 1  Priya   21  Mumbai
# 2   Amit   23  Nashik
# 3   Neha   22   Delhi

# %%
data = [
    ['Rahul',22,'Pune'],
    ['Priya',21,'Mumbai'],
    ['Amit',23,'Nashik'],
    ['Neha',22,'Delhi']
]
df = pd.DataFrame(data, columns=['Name','Age','City'])
print(df)
# Out:
#     Name  Age    City
# 0  Rahul   22    Pune
# 1  Priya   21  Mumbai
# 2   Amit   23  Nashik
# 3   Neha   22   Delhi

# %%
print(df['Name'])
# Out:
# 0    Rahul
# 1    Priya
# 2     Amit
# 3     Neha
# Name: Name, dtype: object

# %%
print(df[['Name','City']])
# Out:
#     Name    City
# 0  Rahul    Pune
# 1  Priya  Mumbai
# 2   Amit  Nashik
# 3   Neha   Delhi

# %%
print(df.loc[0:1])
# Out:
#     Name  Age    City
# 0  Rahul   22    Pune
# 1  Priya   21  Mumbai

# %%
print(df.iloc[2])
# Out:
# Name      Amit
# Age         23
# City    Nashik
# Name: 2, dtype: object

# %%
df['Marks'] = [78,85,90,67]
print(df)
# Out:
#     Name  Age    City  Marks
# 0  Rahul   22    Pune     78
# 1  Priya   21  Mumbai     85
# 2   Amit   23  Nashik     90
# 3   Neha   22   Delhi     67

# %%
df['Course'] = ['Python','Java','Python','Data Science']
print(df)
# Out:
#     Name  Age    City  Marks        Course
# 0  Rahul   22    Pune     78        Python
# 1  Priya   21  Mumbai     85          Java
# 2   Amit   23  Nashik     90        Python
# 3   Neha   22   Delhi     67  Data Science

# %%
df = df.drop('City', axis=1)
print(df)
# Out:
#     Name  Age  Marks        Course
# 0  Rahul   22     78        Python
# 1  Priya   21     85          Java
# 2   Amit   23     90        Python
# 3   Neha   22     67  Data Science

# %%
df = df.drop(1)
print(df)
# Out:
#     Name  Age  Marks        Course
# 0  Rahul   22     78        Python
# 2   Amit   23     90        Python
# 3   Neha   22     67  Data Science

# %%
print(df[df['Age'] > 22])
# Out:
#    Name  Age  Marks  Course
# 2  Amit   23     90  Python

# %%
print(df[df['City'] == 'Pune'])
# Out:
#     Name  Age  City  Marks
# 0  Rahul   22  Pune     78

# %%
print(df[(df['Age'] > 21) & (df['City'] == 'Delhi')])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 print(df[(df['Age'] > 21) & (df['City'] == 'Delhi')])
# ...

# %%
['Name', 'Age', 'Maths', 'Science', 'English', 'Computer', 'Percentage']
# Out:
# ['Name', 'Age', 'Maths', 'Science', 'English', 'Computer', 'Percentage']

# %%
print(df[(df['Age'] > 21) & (df['Percentage'] > 75)])
# Out:
#                          Name   Age  Maths  Science  English  Computer  \
# 0             Avani Chaudhari  32.0     85       88     82.0      90.0
# 1     Shravani Goraksha Sukre  34.0     78       80     75.0      82.0
# 4          Ashwin Nitin Dhake  38.0     88       85     84.0       NaN
# 5       Anushka Nilesh Jadhav  33.0     81       79     83.0      85.0
# 7           Riya Vijay Sawant  30.0     95       93     94.0      96.0
# 8         Pradnya Pramod Ghag  37.0     77       75      NaN      81.0
# 9   Samruddhi Vinod Talagatti  34.0     89       87     90.0      91.0
# 10        Srushti Anand Dhoka  32.0     73       76     78.0      80.0
# 12     Sailee Pandit Hingmire  31.0     91       92     88.0      94.0
# 14     Shravani Rajesh Jadhav  33.0     87       85     86.0      88.0
# 15            Tanishka Gawade  36.0     74       78     76.0      79.0
# 16     Leena Ramesh Ghumatkar  30.0     93       91     92.0      95.0
# ...

# %%
df = pd.read_csv("student89.csv")
print(df.head(3))
# Out:
#                       Name   Age  Maths  Science  English  Computer  \
# 0          Avani Chaudhari  32.0     85       88     82.0      90.0
# 1  Shravani Goraksha Sukre  34.0     78       80     75.0      82.0
# 2      Prerana Sachin Veer  31.0     92       89     90.0      95.0
#
#    Percentage
# 0       86.25
# 1       78.75
# 2         NaN

# %%
df = pd.read_csv("students.csv")
print(df[['Name','Marks']])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df = pd.read_csv("students.csv")
#       2 print(df[['Name','Marks']])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd

df = pd.read_csv("student89.csv")
print(df[['Name', 'Percentage']])
# Out:
#                          Name  Percentage
# 0             Avani Chaudhari       86.25
# 1     Shravani Goraksha Sukre       78.75
# 2         Prerana Sachin Veer         NaN
# 3        Shreya Tanaji Jadhav       73.00
# 4          Ashwin Nitin Dhake       86.50
# 5       Anushka Nilesh Jadhav       82.00
# 6           Sarthak Darandale       68.75
# 7           Riya Vijay Sawant       94.50
# 8         Pradnya Pramod Ghag       78.00
# 9   Samruddhi Vinod Talagatti       89.25
# 10        Srushti Anand Dhoka       76.75
# 11          Pooja Vijay Lakhe       82.75
# 12     Sailee Pandit Hingmire       91.25
# 13  Yashshri Prashant Tembare       72.00
# 14     Shravani Rajesh Jadhav       86.50
# 15            Tanishka Gawade       76.75
# 16     Leena Ramesh Ghumatkar       92.75
# 17        Archita Ankur Dhoka       83.00
# 18  Samruddhi Dattatray Gorde       75.00
# 19        Mrunali Nilesh Kore       87.50
# 20  Mangesh Vijaykumar Ghodke         NaN
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Name', 'Age', 'Maths', 'Science', 'English', 'Computer', 'Percentage']

# %%
df = pd.read_excel("students.xlsx")

print(df.head())
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df = pd.read_excel("students.xlsx")
#       3 print(df.head())
#       4 print(df.shape)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...
